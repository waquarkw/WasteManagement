# %% [markdown]
# # THE WORLD BANK WASTE MANAGEMENT CENSUS
#
# Analysis of  Global Waste Managment data available.
#
# Data Source: [https://datacatalog.worldbank.org/search/dataset/0039597]
#
# The World Bank data inventory from 2019.
#
# ## Definitions
#
# - **iso3c** - Abbrevation of the country
# - **country_name** - Name of the Country
# - **gdp** - GDP of the country in Billions for the year 2019
# - **composition_food_organic_waste_percent** - Percentage of organic waste generated per yer.
# - **composition_glass_percent** - Percentage of glass waste
# - **composition_metal_percent** - Percentage of metal waste
# - **composition_other_percent** - Percentage of all other waste
# - **composition_paper_cardboard_percent** - Percentage of paper cardboard waste
# - **composition_plastic_percent** - Percentage of plastic waste
# - **other_information_national_agency_to_enforce_solid_waste_laws_and_regulations** - If there exists a national agency in the country to enforce the laws.
# - **other_information_national_law_governing_solid_waste_management_in_the_country** - If there exists a national law for waste mangement in the country.
# - **other_information_summary_of_key_solid_waste_information_made_available_to_the_public** - If the information of the waste managemnet is made available to public.
# - **population_number_of_people** - Total population of the country.
# - **e_waste_tons_year** - Amount of e-waste generated/year.
# - **total_waste_generated** - Amount of total waste generated by the country/year
#
#
# ### Please make sure to install the altair library by using command
# pip install altair vega_datasets

# %% [markdown]
# # Exploring the Dataset

# %%
import pandas as pd
from pathlib import Path

world_df = pd.read_csv('countrydata.csv')
world_df.shape
# Out:
# (217, 17)

# %%
world_df.columns
# Out:
# Index(['iso3c', 'region_id', 'country_name', 'income_id', 'gdp',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
#        'other_information_national_law_governing_solid_waste_management_in_the_country',
#        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
#        'population_number_of_people', 'e_waste_tons_year',
#        'total_waste_generated'],
#       dtype='object')

# %%
world_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 17 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   iso3c                                                                                  217 non-null    object
#  1   region_id                                                                              217 non-null    object
#  2   country_name                                                                           216 non-null    object
#  3   income_id                                                                              217 non-null    object
#  4   gdp                                                                                    216 non-null    float64
#  5   composition_food_organic_waste_percent                                                 176 non-null    float64
#  6   composition_glass_percent                                                              171 non-null    float64
#  7   composition_metal_percent                                                              170 non-null    float64
#  8   composition_other_percent                                                              175 non-null    float64
#  9   composition_paper_cardboard_percent                                                    176 non-null    float64
#  10  composition_plastic_percent                                                            175 non-null    float64
#  11  other_information_national_agency_to_enforce_solid_waste_laws_and_regulations          164 non-null    object
#  12  other_information_national_law_governing_solid_waste_management_in_the_country         194 non-null    object
#  13  other_information_summary_of_key_solid_waste_information_made_available_to_the_public  73 non-null     object
#  14  population_number_of_people                                                            217 non-null    int64
#  15  e_waste_tons_year                                                                      182 non-null    float64
#  16  total_waste_generated                                                                  215 non-null    float64
# dtypes: float64(9), int64(1), object(7)
# memory usage: 28.9+ KB

# %% [markdown]
# #### Checking for Null Values

# %%
world_df.isnull().sum().sort_values(ascending=False)
# Out:
# other_information_summary_of_key_solid_waste_information_made_available_to_the_public    144
# other_information_national_agency_to_enforce_solid_waste_laws_and_regulations             53
# composition_metal_percent                                                                 47
# composition_glass_percent                                                                 46
# composition_other_percent                                                                 42
# composition_plastic_percent                                                               42
# composition_food_organic_waste_percent                                                    41
# composition_paper_cardboard_percent                                                       41
# e_waste_tons_year                                                                         35
# other_information_national_law_governing_solid_waste_management_in_the_country            23
# total_waste_generated                                                                      2
# gdp                                                                                        1
# country_name                                                                               1
# region_id                                                                                  0
# income_id                                                                                  0
# population_number_of_people                                                                0
# iso3c                                                                                      0
# dtype: int64

# %%
world_df
# Out:
#     iso3c region_id  country_name income_id           gdp  \
# 0     ABW       LCN         Aruba       HIC  35563.312500
# 1     AFG       SAS   Afghanistan       LIC   2057.062256
# 2     AGO       SSF        Angola       LMC   8036.690430
# 3     ALB       ECS       Albania       UMC  13724.058590
# 4     AND       ECS       Andorra       HIC  43711.800780
# ..    ...       ...           ...       ...           ...
# 212   XKX       ECS        Kosovo       LMC   9723.561523
# 213   YEM       MEA   Yemen, Rep.       LIC   8269.671875
# 214   ZAF       SSF  South Africa       UMC  12666.607420
# 215   ZMB       SSF        Zambia       LMC   3201.289307
# 216   ZWE       SSF      Zimbabwe       LIC   3190.506592
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                       NaN                        NaN
# 1                                       NaN                        NaN
# 2                                 51.800000                   6.700000
# 3                                 51.400000                   4.500000
# 4                                 31.200000                   8.200000
# ..                                      ...                        ...
# 212                               42.000000                   6.000000
# 213                               65.000000                   1.000000
# 214                               16.381655                   5.200216
# 215                                     NaN                        NaN
# 216                               36.000000                   5.000000
#
#      composition_metal_percent  composition_other_percent  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                     4.400000                  11.500000
# 3                     4.800000                  15.210000
# 4                     2.600000                  11.600000
# ..                         ...                        ...
# 212                   6.000000                  20.000000
# 213                   6.000000                   6.000000
# 214                  16.910461                  45.020646
# 215                        NaN                        NaN
# 216                   6.000000                   3.000000
#
#      composition_paper_cardboard_percent  composition_plastic_percent  \
# 0                                    NaN                          NaN
# 1                                    NaN                          NaN
# 2                              11.900000                    13.500000
# 3                               9.900000                     9.600000
# 4                              35.100000                    11.300000
# ..                                   ...                          ...
# 212                             8.000000                    11.000000
# 213                             7.000000                    10.000000
# 214                             9.396918                     7.090104
# 215                                  NaN                          NaN
# 216                            27.000000                    23.000000
#
#     other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  NaN
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 212                                                Yes
# 213                                                Yes
# 214                                                Yes
# 215                                                NaN
# 216                                                NaN
#
#     other_information_national_law_governing_solid_waste_management_in_the_country  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 212                                                Yes
# 213                                                Yes
# 214                                                Yes
# 215                                                Yes
# 216                                                Yes
#
#     other_information_summary_of_key_solid_waste_information_made_available_to_the_public  \
# 0                                                  Yes
# 1                                                  NaN
# 2                                                  NaN
# 3                                                   No
# 4                                                  NaN
# ..                                                 ...
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
#
#      population_number_of_people  e_waste_tons_year  total_waste_generated
# 0                         103187                NaN           8.813202e+04
# 1                       34656032            20000.0           5.628525e+06
# 2                       25096150            92000.0           4.213644e+06
# 3                        2854191            20000.0           1.087447e+06
# 4                          82431                NaN           4.300000e+04
# ..                           ...                ...                    ...
# 212                      1801800               23.0           3.190000e+05
# 213                     27584212            42000.0           4.836820e+06
# 214                     51729344           321000.0           1.845723e+07
# 215                     14264756            15000.0           2.608268e+06
# 216                     12500525            13000.0           1.449752e+06
#
# [217 rows x 17 columns]

# %% [markdown]
# ## Exploring the Columns
#
# The columns of interest for this analysis include:
#
# - iso3c
# - country_name
# - gdp
# - composition_food_organic_waste_percent
# - other_information_national_law_governing_solid_waste_management_in_the_country
# - other_information_summary_of_key_solid_waste_information_made_available_to_the_public
# - population_number_of_people
# - e_waste_tons_year
# - total_waste_generated
#
#
# The following column will be removed from the clean data:
# - other_information_national_agency_to_enforce_solid_waste_laws_and_regulations
# - composition_glass_percent
# - composition_metal_percent
# - composition_other_percent
# - composition_paper_cardboard_percent
# - composition_plastic_percent

# %% [markdown]
# #### Checking for percentage of food organic waste

# %%
world_df['composition_food_organic_waste_percent'].value_counts()
# Out:
# 43.600000    6
# 30.000000    6
# 57.000000    5
# 46.000000    5
# 45.000000    3
#             ..
# 35.880000    1
# 87.600000    1
# 36.700000    1
# 49.000000    1
# 16.381655    1
# Name: composition_food_organic_waste_percent, Length: 135, dtype: int64

# %% [markdown]
# #### Checking amount of countries that come under High income, medium income, low to medium income and low income countries.

# %%
world_df['income_id'].value_counts()
# Out:
# HIC    81
# UMC    56
# LMC    47
# LIC    33
# Name: income_id, dtype: int64

# %%
bins = [10000000, 20000000, 30000000, 40000000, 50000000, 600000000000000000]
labels = ['<10M', '<20M', '<30M', '<40M', '<50M']
world_df['population_buckets'] = pd.cut(world_df['population_number_of_people'], bins=bins, labels=labels, right=False)
world_df['population_buckets'].value_counts().apply(lambda x: format(int(x), 'n'))
# Out:
# <10M    27
# <50M    25
# <20M    14
# <30M    10
# <40M     8
# Name: population_buckets, dtype: object

# %%
world_df[world_df['total_waste_generated'] < 100000]
# Out:
#     iso3c region_id                    country_name income_id           gdp  \
# 0     ABW       LCN                           Aruba       HIC  35563.312500
# 4     AND       ECS                         Andorra       HIC  43711.800780
# 8     ASM       EAS                  American Samoa       UMC  11113.442380
# 9     ATG       LCN             Antigua and Barbuda       HIC  17965.501950
# 24    BMU       NAC                         Bermuda       HIC  80982.367190
# 42    COM       SSF                         Comoros       LIC   2959.540039
# 46    CUW       LCN                         Curacao       HIC  27503.789060
# 47    CYM       LCN                  Cayman Islands       HIC  66207.445310
# 52    DMA       LCN                        Dominica       UMC  11708.639650
# 65    FRO       ECS                  Faeroe Islands       HIC  44402.878910
# 66    FSM       EAS           Micronesia, Fed. Sts.       LMC   3440.064209
# 71    GIB       ECS                       Gibraltar       HIC  43711.800780
# 77    GRD       LCN                         Grenada       UMC  13207.711910
# 78    GRL       ECS                       Greenland       HIC  43948.562500
# 88    IMN       ECS                     Isle of Man       HIC  44203.621090
# 103   KIR       EAS                        Kiribati       LMC   2249.768555
# 104   KNA       LCN             St. Kitts and Nevis       HIC  25569.357420
# 111   LCA       LCN                       St. Lucia       UMC  14029.982420
# 112   LIE       ECS                   Liechtenstein       HIC  45726.988280
# 114   LSO       SSF                         Lesotho       LMC   1978.608398
# 119   MAF       LCN        St. Martin (French part)       HIC  30385.894530
# 121   MCO       ECS                          Monaco       HIC  43711.800780
# 126   MHL       EAS                Marshall Islands       UMC   3628.895264
# 133   MNP       EAS        Northern Mariana Islands       HIC  60955.726560
# 147   NRU       EAS                           Nauru       UMC  11167.319340
# 154   PLW       EAS                           Palau       HIC  18275.025390
# 173   SMR       ECS                      San Marino       HIC  58806.199220
# 177   STP       SSF           São Tomé and Príncipe       LMC   3720.786865
# 178   SUR       LCN                        Suriname       UMC  16953.802730
# 184   SYC       SSF                      Seychelles       HIC  23302.953130
# 192   TLS       EAS                     Timor-Leste       LMC   3344.573730
# 193   TON       EAS                           Tonga       UMC   5636.418457
# 197   TUV       EAS                          Tuvalu       UMC   3793.127686
# 205   VCT       LCN  St. Vincent and the Grenadines       UMC  11971.993160
# 207   VGB       LCN          British Virgin Islands       HIC  24215.882810
# 210   VUT       EAS                         Vanuatu       LMC   3061.787354
# 211   WSM       EAS                           Samoa       UMC   6210.983398
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                       NaN                        NaN
# 4                                     31.20                       8.20
# 8                                     19.70                       3.40
# 9                                     46.00                       7.00
# 24                                    17.00                       9.00
# 42                                    50.00                       2.00
# 46                                      NaN                        NaN
# 47                                    10.90                       3.50
# 52                                    45.00                       8.00
# 65                                      NaN                        NaN
# 66                                    23.83                       7.07
# 71                                    24.57                       4.42
# 77                                    27.10                       3.10
# 78                                    42.80                       7.10
# 88                                      NaN                        NaN
# 103                                   43.60                       5.50
# 104                                   27.20                       8.10
# 111                                   45.00                       7.00
# 112                                   37.60                       5.00
# 114                                     NaN                        NaN
# 119                                     NaN                        NaN
# 121                                     NaN                       3.00
# 126                                    8.00                       2.00
# 133                                   43.60                       5.50
# 147                                   43.60                       5.50
# 154                                   26.00                       5.00
# 173                                    5.35                       5.61
# 177                                     NaN                        NaN
# 178                                   57.00                       3.00
# 184                                   48.50                       5.20
# 192                                   43.60                       5.50
# 193                                   51.30                       5.90
# 197                                   43.60                       5.50
# 205                                   49.60                       5.60
# 207                                    6.50                      18.10
# 210                                   73.40                       5.40
# 211                                   42.60                       2.20
#
#      composition_metal_percent  composition_other_percent  \
# 0                          NaN                        NaN
# 4                         2.60                      11.60
# 8                         7.90                      25.60
# 9                         7.00                      12.00
# 24                        6.00                      26.00
# 42                        4.00                      22.00
# 46                         NaN                        NaN
# 47                        6.20                      11.40
# 52                        5.00                      14.00
# 65                         NaN                        NaN
# 66                       16.73                       9.32
# 71                        4.37                      14.38
# 77                        2.40                      36.50
# 78                        2.00                      33.40
# 88                         NaN                        NaN
# 103                      10.00                       9.30
# 104                       8.80                      12.20
# 111                       5.00                      11.00
# 112                      12.50                       9.10
# 114                        NaN                        NaN
# 119                        NaN                        NaN
# 121                       2.20                        NaN
# 126                       6.00                      31.00
# 133                      10.00                       9.30
# 147                      10.00                       9.30
# 154                      10.00                       9.00
# 173                       0.90                      65.56
# 177                        NaN                        NaN
# 178                       3.00                      24.00
# 184                       4.60                      25.80
# 192                      10.00                       9.30
# 193                       9.00                       8.90
# 197                      10.00                       9.30
# 205                       3.80                      10.50
# 207                       8.60                       4.80
# 210                       3.80                       5.70
# 211                       8.80                      19.40
#
#      composition_paper_cardboard_percent  composition_plastic_percent  \
# 0                                    NaN                          NaN
# 4                                  35.10                        11.30
# 8                                  26.40                        12.80
# 9                                  15.00                        13.00
# 24                                 29.00                        13.00
# 42                                  7.00                         5.00
# 46                                   NaN                          NaN
# 47                                 31.10                        11.00
# 52                                 12.00                        16.00
# 65                                   NaN                          NaN
# 66                                 13.30                        26.17
# 71                                 33.65                        15.86
# 77                                 13.60                        16.40
# 78                                 11.40                         2.40
# 88                                   NaN                          NaN
# 103                                10.90                        16.50
# 104                                20.50                        23.20
# 111                                10.00                        22.00
# 112                                30.30                         5.40
# 114                                  NaN                          NaN
# 119                                  NaN                          NaN
# 121                                 2.20                         1.00
# 126                                11.00                        13.00
# 133                                10.90                        16.50
# 147                                10.90                        16.50
# 154                                15.00                        32.00
# 173                                13.21                         5.60
# 177                                  NaN                          NaN
# 178                                  NaN                        11.00
# 184                                 5.90                         9.90
# 192                                10.90                        16.50
# 193                                 7.40                        13.40
# 197                                10.90                        16.50
# 205                                22.10                         8.40
# 207                                33.50                         6.30
# 210                                 4.05                         6.45
# 211                                 7.20                        13.00
#
#     other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# 0                                                  Yes
# 4                                                  Yes
# 8                                                  Yes
# 9                                                  Yes
# 24                                                 Yes
# 42                                                 NaN
# 46                                                 Yes
# 47                                                 Yes
# 52                                                 Yes
# 65                                                 NaN
# 66                                                 Yes
# 71                                                 Yes
# 77                                                 Yes
# 78                                                 NaN
# 88                                                 Yes
# 103                                                Yes
# 104                                                Yes
# 111                                                Yes
# 112                                                Yes
# 114                                                NaN
# 119                                                NaN
# 121                                                Yes
# 126                                                Yes
# 133                                                Yes
# 147                                                Yes
# 154                                               None
# 173                                                NaN
# 177                                                NaN
# 178                                                 No
# 184                                                Yes
# 192                                                Yes
# 193                                                Yes
# 197                                                Yes
# 205                                                Yes
# 207                                                Yes
# 210                                                Yes
# 211                                                Yes
#
#     other_information_national_law_governing_solid_waste_management_in_the_country  \
# 0                                                  Yes
# 4                                                  Yes
# 8                                                  NaN
# 9                                                  Yes
# 24                                                 Yes
# 42                                                 Yes
# 46                                                 Yes
# 47                                                 Yes
# 52                                                 Yes
# 65                                                 Yes
# 66                                                 Yes
# 71                                                 Yes
# 77                                                 Yes
# 78                                                 Yes
# 88                                                 Yes
# 103                                                Yes
# 104                                                Yes
# 111                                                Yes
# 112                                                Yes
# 114                                                NaN
# 119                                                Yes
# 121                                                Yes
# 126                                                Yes
# 133                                                Yes
# 147                                                Yes
# 154                                                Yes
# 173                                                NaN
# 177                                                NaN
# 178                                                 No
# 184                                                Yes
# 192                                                Yes
# 193                                                Yes
# 197                                                Yes
# 205                                                Yes
# 207                                                Yes
# 210                                                Yes
# 211                                                Yes
#
#     other_information_summary_of_key_solid_waste_information_made_available_to_the_public  \
# 0                                                  Yes
# 4                                                  NaN
# 8                                                  NaN
# 9                                                   No
# 24                                                 NaN
# 42                                                 NaN
# 46                                                 NaN
# 47                                                 NaN
# 52                                                 NaN
# 65                                                 NaN
# 66                                                 NaN
# 71                                                 Yes
# 77                                                 NaN
# 78                                                 NaN
# 88                                                 Yes
# 103                                                NaN
# 104                                                Yes
# 111                                                Yes
# 112                                                NaN
# 114                                                NaN
# 119                                                Yes
# 121                                                Yes
# 126                                                NaN
# 133                                                Yes
# 147                                                NaN
# 154                                                Yes
# 173                                                NaN
# 177                                                NaN
# 178                                                 No
# 184                                                Yes
# 192                                                NaN
# 193                                                NaN
# 197                                                NaN
# 205                                                Yes
# 207                                                Yes
# 210                                                NaN
# 211                                                Yes
#
#      population_number_of_people  e_waste_tons_year  total_waste_generated  \
# 0                         103187                NaN            88132.01670
# 4                          82431                NaN            43000.00000
# 8                          55599                NaN            18989.49000
# 9                          96777            1100.00            30585.00000
# 24                         64798                NaN            82000.00000
# 42                        777424             600.00            91013.00000
# 46                        153822                NaN            24703.81320
# 47                         59172                NaN            60000.00000
# 52                         72400                NaN            13176.00000
# 65                         48842                NaN            61000.00000
# 66                        104937             200.00            26039.57000
# 71                         33623             201.44            16954.00000
# 77                        105481             800.00            29536.11394
# 78                         56905                NaN            50000.00000
# 88                         80759                NaN            50551.00000
# 103                       114395             100.00            35723.82750
# 104                        54288             700.00            32892.14000
# 111                       177206            1600.00            77616.22800
# 112                        36545             293.00            32382.00000
# 114                      1965662            1800.00            73457.00000
# 119                        30959                NaN            15479.50000
# 121                        37783                NaN            46000.00000
# 126                        52793                NaN             8614.00000
# 133                        54036                NaN            32761.41450
# 147                        13049                NaN             6191.75050
# 154                        21503             200.00             9426.74550
# 173                        33203                NaN            17174.68000
# 177                       191266             200.00            25586.50000
# 178                       526103            5000.00            78619.79915
# 184                        88303            1100.00            48000.00000
# 192                      1268671            3600.00            63875.00000
# 193                       104951             300.00            17238.20175
# 197                        11097              10.00             3989.48650
# 205                       109455             900.00            31561.34925
# 207                        20645                NaN            21099.19000
# 210                       270402             300.00            70225.48900
# 211                       187665             500.00            27399.09000
#
#     population_buckets
# 0                  NaN
# 4                  NaN
# 8                  NaN
# 9                  NaN
# 24                 NaN
# 42                 NaN
# 46                 NaN
# 47                 NaN
# 52                 NaN
# 65                 NaN
# 66                 NaN
# 71                 NaN
# 77                 NaN
# 78                 NaN
# 88                 NaN
# 103                NaN
# 104                NaN
# 111                NaN
# 112                NaN
# 114                NaN
# 119                NaN
# 121                NaN
# 126                NaN
# 133                NaN
# 147                NaN
# 154                NaN
# 173                NaN
# 177                NaN
# 178                NaN
# 184                NaN
# 192                NaN
# 193                NaN
# 197                NaN
# 205                NaN
# 207                NaN
# 210                NaN
# 211                NaN

# %%
world_df[world_df['total_waste_generated'] > 10000000]
# Out:
#     iso3c region_id        country_name income_id           gdp  \
# 6     ARG       LCN           Argentina       HIC  23550.099610
# 10    AUS       EAS           Australia       HIC  47784.179690
# 17    BGD       SAS          Bangladesh       LMC   3195.737061
# 26    BRA       LCN              Brazil       UMC  14596.246090
# 32    CAN       NAC              Canada       HIC  47672.078130
# 36    CHN       EAS               China       UMC  16092.300780
# 39    COD       SSF    Congo, Dem. Rep.       LIC   1055.572998
# 41    COL       LCN            Colombia       UMC  12523.006840
# 50    DEU       ECS             Germany       HIC  53784.781250
# 55    DZA       MEA             Algeria       UMC  11826.165040
# 57    EGY       MEA    Egypt, Arab Rep.       LMC  10301.107420
# 59    ESP       ECS               Spain       HIC  40985.558590
# 64    FRA       ECS              France       HIC  46110.183590
# 68    GBR       ECS      United Kingdom       HIC  46290.121090
# 87    IDN       EAS           Indonesia       LMC  10531.198240
# 89    IND       SAS               India       LMC   6496.807617
# 91    IRN       MEA  Iran, Islamic Rep.       UMC  14535.862300
# 92    IRQ       MEA                Iraq       UMC  10310.679690
# 95    ITA       ECS               Italy       HIC  42419.722660
# 98    JPN       EAS               Japan       HIC  41309.957030
# 105   KOR       EAS         Korea, Rep.       HIC  42105.281250
# 125   MEX       LCN              Mexico       UMC  19332.074220
# 138   MYS       EAS            Malaysia       UMC  23906.265630
# 142   NGA       SSF             Nigeria       LMC   4690.379395
# 150   PAK       SAS            Pakistan       LMC   4571.414551
# 153   PHL       EAS         Philippines       LMC   7705.045410
# 156   POL       ECS              Poland       HIC  33221.542970
# 164   RUS       ECS  Russian Federation       UMC  26012.849610
# 166   SAU       MEA        Saudi Arabia       HIC  48921.230470
# 189   THA       EAS            Thailand       UMC  16301.538090
# 196   TUR       ECS              Turkey       UMC  28289.087890
# 201   UKR       ECS             Ukraine       LMC  11534.637700
# 203   USA       NAC       United States       HIC  61498.371090
# 214   ZAF       SSF        South Africa       UMC  12666.607420
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 6                                 38.740000                   3.160000
# 10                                48.440000                   3.810000
# 17                                80.580000                   0.440000
# 26                                51.400000                   2.400000
# 32                                24.000000                   6.000000
# 36                                61.200000                   2.100000
# 39                                      NaN                        NaN
# 41                                59.580000                   2.350000
# 50                                30.000000                  10.000000
# 55                                54.400000                   1.200000
# 57                                56.000000                   4.000000
# 59                                49.000000                   8.000000
# 64                                32.000000                  10.000000
# 68                                16.700000                   2.200000
# 87                                53.800000                   2.500000
# 89                                      NaN                        NaN
# 91                                72.900000                   1.900000
# 92                                68.700000                   2.300000
# 95                                34.400000                   7.600000
# 98                                36.000000                   5.000000
# 105                               30.000000                   2.500000
# 125                               52.400000                   5.900000
# 138                               46.000000                   3.000000
# 142                                     NaN                   3.100000
# 150                               30.000000                   6.000000
# 153                               52.310000                   2.340000
# 156                               37.270000                  10.070000
# 164                               28.410000                  16.820000
# 166                               45.500000                   4.000000
# 189                               65.520000                   3.040000
# 196                               64.000000                   2.000000
# 201                               37.000000                   5.000000
# 203                               14.900000                   4.400000
# 214                               16.381655                   5.200216
#
#      composition_metal_percent  composition_other_percent  \
# 6                     1.840000                  15.360000
# 10                   19.380000                   3.460000
# 17                    0.500000                   8.590000
# 26                    2.900000                  16.700000
# 32                   13.000000                   8.000000
# 36                    1.100000                  13.100000
# 39                         NaN                        NaN
# 41                    1.100000                  15.740000
# 50                    1.400000                  17.700000
# 55                    2.800000                   0.800000
# 57                    2.000000                  15.000000
# 59                    3.000000                  14.000000
# 64                    3.000000                  26.000000
# 68                    3.500000                  28.200000
# 87                    1.800000                  12.900000
# 89                         NaN                        NaN
# 91                    2.300000                   5.000000
# 92                    0.980000                   6.000000
# 95                    4.300000                  15.400000
# 98                    4.000000                   6.000000
# 105                   2.600000                        NaN
# 125                   3.400000                  12.100000
# 138                   3.000000                   9.000000
# 142                        NaN                  11.300000
# 150                   4.000000                  20.000000
# 153                   4.220000                  21.520000
# 156                   2.170000                  26.690000
# 164                   1.830000                  19.030000
# 166                   5.000000                   2.500000
# 189                   1.850000                   4.740000
# 196                   1.000000                  24.000000
# 201                   4.000000                  22.000000
# 203                   9.000000                   3.200000
# 214                  16.910461                  45.020646
#
#      composition_paper_cardboard_percent  composition_plastic_percent  \
# 6                              13.960000                    14.610000
# 10                             17.300000                     7.610000
# 17                              3.040000                     4.670000
# 26                             13.100000                    13.500000
# 32                             47.000000                     3.000000
# 36                              9.600000                     9.800000
# 39                                   NaN                          NaN
# 41                              8.400000                    12.830000
# 50                             24.000000                    13.000000
# 55                              9.800000                    16.900000
# 57                             10.000000                    13.000000
# 59                             15.000000                     9.000000
# 64                             20.000000                     9.000000
# 68                             18.900000                    20.200000
# 87                             14.900000                    14.000000
# 89                                   NaN                          NaN
# 91                              7.300000                     8.500000
# 92                              9.600000                     5.290000
# 95                             22.800000                    11.600000
# 98                             33.000000                    11.000000
# 105                            41.000000                    24.300000
# 125                            13.800000                    10.900000
# 138                            14.000000                    15.000000
# 142                             8.000000                     4.800000
# 150                            13.000000                     9.000000
# 153                             8.700000                    10.550000
# 156                            11.270000                    12.130000
# 164                            19.700000                    14.210000
# 166                            27.000000                    11.000000
# 189                             7.600000                    17.590000
# 196                             6.000000                     3.000000
# 201                            25.000000                     7.000000
# 203                            26.600000                    12.900000
# 214                             9.396918                     7.090104
#
#     other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# 6                                                  NaN
# 10                                                 Yes
# 17                                                 Yes
# 26                                                 Yes
# 32                                                 Yes
# 36                                                 Yes
# 39                                                 NaN
# 41                                                 NaN
# 50                                                 Yes
# 55                                                 Yes
# 57                                                 Yes
# 59                                                 Yes
# 64                                                 Yes
# 68                                                 Yes
# 87                                                 Yes
# 89                                                 Yes
# 91                                                 Yes
# 92                                                  No
# 95                                                 Yes
# 98                                                  No
# 105                                                Yes
# 125                                                NaN
# 138                                                Yes
# 142                                                NaN
# 150                                                Yes
# 153                                                Yes
# 156                                                Yes
# 164                                                Yes
# 166                                                Yes
# 189                                                Yes
# 196                                                Yes
# 201                                                Yes
# 203                                                Yes
# 214                                                Yes
#
#     other_information_national_law_governing_solid_waste_management_in_the_country  \
# 6                                                  Yes
# 10                                                 Yes
# 17                                                 Yes
# 26                                                 Yes
# 32                                                 Yes
# 36                                                 Yes
# 39                                                 Yes
# 41                                                  No
# 50                                                 Yes
# 55                                                 Yes
# 57                                                  No
# 59                                                 Yes
# 64                                                 Yes
# 68                                                 Yes
# 87                                                 Yes
# 89                                                 Yes
# 91                                                 Yes
# 92                                                  No
# 95                                                 Yes
# 98                                                 Yes
# 105                                                Yes
# 125                                                Yes
# 138                                                Yes
# 142                                                Yes
# 150                                                 No
# 153                                                Yes
# 156                                                Yes
# 164                                                Yes
# 166                                                yes
# 189                                                Yes
# 196                                                Yes
# 201                                                Yes
# 203                                                Yes
# 214                                                Yes
#
#     other_information_summary_of_key_solid_waste_information_made_available_to_the_public  \
# 6                                                  NaN
# 10                                                 Yes
# 17                                                 NaN
# 26                                                 NaN
# 32                                                 Yes
# 36                                                 NaN
# 39                                                 NaN
# 41                                                 NaN
# 50                                                 Yes
# 55                                                 Yes
# 57                                                 NaN
# 59                                                 Yes
# 64                                                 NaN
# 68                                                 NaN
# 87                                                 NaN
# 89                                                 Yes
# 91                                                  No
# 92                                                 NaN
# 95                                                 NaN
# 98                                                 NaN
# 105                                                NaN
# 125                                                NaN
# 138                                                Yes
# 142                                                NaN
# 150                                                NaN
# 153                                                Yes
# 156                                                NaN
# 164                                                NaN
# 166                                                NaN
# 189                                                NaN
# 196                                                NaN
# 201                                                NaN
# 203                                                Yes
# 214                                                NaN
#
#      population_number_of_people  e_waste_tons_year  total_waste_generated  \
# 6                       42981516           291700.0           1.791055e+07
# 10                      23789338           574000.0           1.334500e+07
# 17                     155727056           142000.0           1.477850e+07
# 26                     208494896          1411900.0           7.906958e+07
# 32                      35544564           724000.0           2.510303e+07
# 36                    1400050048          7211000.0           3.950814e+08
# 39                      78736152                NaN           1.438523e+07
# 41                      46406648           252200.0           1.215012e+07
# 50                      83132800          2465085.0           5.062788e+07
# 55                      40606052           252000.0           1.237874e+07
# 57                      87813256           497000.0           2.100000e+07
# 59                      47076780          1202597.0           2.240855e+07
# 64                      67059888          2218682.0           3.674882e+07
# 68                      66460344          3584126.0           3.077114e+07
# 87                     261115456          1274000.0           6.520000e+07
# 89                    1352617344          1700000.0           1.897500e+08
# 91                      80277424           630000.0           1.788500e+07
# 92                      36115648           221000.0           1.314000e+07
# 95                      60297396          2800026.0           3.008840e+07
# 98                     126529104           518978.0           4.272000e+07
# 105                     51606632           570635.0           2.045278e+07
# 125                    125890952           957900.0           5.310000e+07
# 138                     30228016           280000.0           1.298268e+07
# 142                    154402176           277000.0           2.761483e+07
# 150                    193203472           301000.0           3.076000e+07
# 153                    103320224           290000.0           1.463192e+07
# 156                     37970872           224452.0           1.275821e+07
# 164                    143201680          1392000.0           6.000000e+07
# 166                     31557144           508000.0           1.612570e+07
# 189                     68657600           384233.0           2.685337e+07
# 196                     83429616           623000.0           3.537416e+07
# 201                     45004644           277000.0           1.524202e+07
# 203                    326687488          2440000.0           2.652245e+08
# 214                     51729344           321000.0           1.845723e+07
#
#     population_buckets
# 6                 <40M
# 10                <20M
# 17                <50M
# 26                <50M
# 32                <30M
# 36                <50M
# 39                <50M
# 41                <40M
# 50                <50M
# 55                <40M
# 57                <50M
# 59                <40M
# 64                <50M
# 68                <50M
# 87                <50M
# 89                <50M
# 91                <50M
# 92                <30M
# 95                <50M
# 98                <50M
# 105               <50M
# 125               <50M
# 138               <30M
# 142               <50M
# 150               <50M
# 153               <50M
# 156               <30M
# 164               <50M
# 166               <30M
# 189               <50M
# 196               <50M
# 201               <40M
# 203               <50M
# 214               <50M

# %%
world_df[world_df['e_waste_tons_year'].isna()]
# Out:
#     iso3c region_id               country_name income_id           gdp  \
# 0     ABW       LCN                      Aruba       HIC  35563.312500
# 4     AND       ECS                    Andorra       HIC  43711.800780
# 8     ASM       EAS             American Samoa       UMC  11113.442380
# 24    BMU       NAC                    Bermuda       HIC  80982.367190
# 34    CHI       ECS            Channel Islands       HIC  46672.593750
# 39    COD       SSF           Congo, Dem. Rep.       LIC   1055.572998
# 40    COG       SSF                Congo, Rep.       LMC   4899.579590
# 45    CUB       LCN                       Cuba       UMC  12984.710940
# 46    CUW       LCN                    Curacao       HIC  27503.789060
# 47    CYM       LCN             Cayman Islands       HIC  66207.445310
# 52    DMA       LCN                   Dominica       UMC  11708.639650
# 65    FRO       ECS             Faeroe Islands       HIC  44402.878910
# 75    GNQ       SSF          Equatorial Guinea       UMC  24827.072270
# 78    GRL       ECS                  Greenland       HIC  43948.562500
# 80    GUM       EAS                       Guam       HIC  59074.941410
# 88    IMN       ECS                Isle of Man       HIC  44203.621090
# 109   LBR       SSF                    Liberia       LIC   1333.422241
# 119   MAF       LCN   St. Martin (French part)       HIC  30385.894530
# 121   MCO       ECS                     Monaco       HIC  43711.800780
# 126   MHL       EAS           Marshall Islands       UMC   3628.895264
# 133   MNP       EAS   Northern Mariana Islands       HIC  60955.726560
# 140   NCL       EAS              New Caledonia       HIC  57330.203130
# 147   NRU       EAS                      Nauru       UMC  11167.319340
# 160   PSE       MEA         West Bank and Gaza       LMC   5985.683105
# 161   PYF       EAS           French Polynesia       HIC  60955.726560
# 173   SMR       ECS                 San Marino       HIC  58806.199220
# 174   SOM       SSF                    Somalia       LIC   1862.614136
# 176   SSD       SSF                South Sudan       LIC   1795.991943
# 183   SXM       LCN  Sint Maarten (Dutch part)       HIC           NaN
# 185   SYR       MEA       Syrian Arab Republic       LIC   8587.050781
# 186   TCA       LCN   Turks and Caicos Islands       HIC  28174.482420
# 190   TJK       ECS                 Tajikistan       LIC   2616.475586
# 204   UZB       ECS                 Uzbekistan       LMC   5164.274414
# 207   VGB       LCN     British Virgin Islands       HIC  24215.882810
# 208   VIR       LCN      Virgin Islands (U.S.)       HIC  30436.564450
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                       NaN                        NaN
# 4                                     31.20                       8.20
# 8                                     19.70                       3.40
# 24                                    17.00                       9.00
# 34                                      NaN                        NaN
# 39                                      NaN                        NaN
# 40                                      NaN                        NaN
# 45                                    68.90                       4.60
# 46                                      NaN                        NaN
# 47                                    10.90                       3.50
# 52                                    45.00                       8.00
# 65                                      NaN                        NaN
# 75                                      NaN                        NaN
# 78                                    42.80                       7.10
# 80                                    27.30                       4.60
# 88                                      NaN                        NaN
# 109                                     NaN                        NaN
# 119                                     NaN                        NaN
# 121                                     NaN                       3.00
# 126                                    8.00                       2.00
# 133                                   43.60                       5.50
# 140                                   43.60                       5.50
# 147                                   43.60                       5.50
# 160                                   59.10                       2.40
# 161                                   47.00                       3.00
# 173                                    5.35                       5.61
# 174                                     NaN                        NaN
# 176                                     NaN                        NaN
# 183                                   46.00                       7.00
# 185                                   57.00                       3.00
# 186                                   21.80                      20.50
# 190                                     NaN                        NaN
# 204                                   40.00                       3.00
# 207                                    6.50                      18.10
# 208                                   46.00                       7.00
#
#      composition_metal_percent  composition_other_percent  \
# 0                          NaN                        NaN
# 4                          2.6                      11.60
# 8                          7.9                      25.60
# 24                         6.0                      26.00
# 34                         NaN                        NaN
# 39                         NaN                        NaN
# 40                         NaN                        NaN
# 45                         1.6                       3.00
# 46                         NaN                        NaN
# 47                         6.2                      11.40
# 52                         5.0                      14.00
# 65                         NaN                        NaN
# 75                         NaN                        NaN
# 78                         2.0                      33.40
# 80                         9.0                       8.70
# 88                         NaN                        NaN
# 109                        NaN                        NaN
# 119                        NaN                        NaN
# 121                        2.2                        NaN
# 126                        6.0                      31.00
# 133                       10.0                       9.30
# 140                       10.0                       9.30
# 147                       10.0                       9.30
# 160                        2.7                      11.50
# 161                        3.0                      29.00
# 173                        0.9                      65.56
# 174                        NaN                        NaN
# 176                        NaN                        NaN
# 183                        7.0                      12.00
# 185                        4.0                      22.00
# 186                        7.6                       2.40
# 190                        NaN                        NaN
# 204                        2.0                      17.50
# 207                        8.6                       4.80
# 208                        7.0                      12.00
#
#      composition_paper_cardboard_percent  composition_plastic_percent  \
# 0                                    NaN                          NaN
# 4                                  35.10                         11.3
# 8                                  26.40                         12.8
# 24                                 29.00                         13.0
# 34                                   NaN                          NaN
# 39                                   NaN                          NaN
# 40                                   NaN                          NaN
# 45                                 12.30                          9.6
# 46                                   NaN                          NaN
# 47                                 31.10                         11.0
# 52                                 12.00                         16.0
# 65                                   NaN                          NaN
# 75                                   NaN                          NaN
# 78                                 11.40                          2.4
# 80                                 28.50                         12.4
# 88                                   NaN                          NaN
# 109                                  NaN                          NaN
# 119                                  NaN                          NaN
# 121                                 2.20                          1.0
# 126                                11.00                         13.0
# 133                                10.90                         16.5
# 140                                10.90                         16.5
# 147                                10.90                         16.5
# 160                                10.10                         14.2
# 161                                16.00                          2.0
# 173                                13.21                          5.6
# 174                                  NaN                          NaN
# 176                                  NaN                          NaN
# 183                                15.00                         13.0
# 185                                 7.00                          7.0
# 186                                31.50                         16.3
# 190                                  NaN                          NaN
# 204                                17.50                          2.5
# 207                                33.50                          6.3
# 208                                15.00                         13.0
#
#     other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# 0                                                  Yes
# 4                                                  Yes
# 8                                                  Yes
# 24                                                 Yes
# 34                                                 Yes
# 39                                                 NaN
# 40                                                  No
# 45                                                  No
# 46                                                 Yes
# 47                                                 Yes
# 52                                                 Yes
# 65                                                 NaN
# 75                                                 NaN
# 78                                                 NaN
# 80                                                 Yes
# 88                                                 Yes
# 109                                                Yes
# 119                                                NaN
# 121                                                Yes
# 126                                                Yes
# 133                                                Yes
# 140                                                NaN
# 147                                                Yes
# 160                                                Yes
# 161                                                Yes
# 173                                                NaN
# 174                                                NaN
# 176                                                NaN
# 183                                                Yes
# 185                                                Yes
# 186                                                NaN
# 190                                                Yes
# 204                                                Yes
# 207                                                Yes
# 208                                                Yes
#
#     other_information_national_law_governing_solid_waste_management_in_the_country  \
# 0                                                  Yes
# 4                                                  Yes
# 8                                                  NaN
# 24                                                 Yes
# 34                                                 Yes
# 39                                                 Yes
# 40                                                 Yes
# 45                                                  No
# 46                                                 Yes
# 47                                                 Yes
# 52                                                 Yes
# 65                                                 Yes
# 75                                                 NaN
# 78                                                 Yes
# 80                                                 Yes
# 88                                                 Yes
# 109                                                Yes
# 119                                                Yes
# 121                                                Yes
# 126                                                Yes
# 133                                                Yes
# 140                                                Yes
# 147                                                Yes
# 160                                                Yes
# 161                                                 No
# 173                                                NaN
# 174                                                NaN
# 176                                                NaN
# 183                                                Yes
# 185                                                Yes
# 186                                                Yes
# 190                                                Yes
# 204                                                Yes
# 207                                                Yes
# 208                                                Yes
#
#     other_information_summary_of_key_solid_waste_information_made_available_to_the_public  \
# 0                                                  Yes
# 4                                                  NaN
# 8                                                  NaN
# 24                                                 NaN
# 34                                                 NaN
# 39                                                 NaN
# 40                                                 NaN
# 45                                                 Yes
# 46                                                 NaN
# 47                                                 NaN
# 52                                                 NaN
# 65                                                 NaN
# 75                                                 NaN
# 78                                                 NaN
# 80                                                 Yes
# 88                                                 Yes
# 109                                                NaN
# 119                                                Yes
# 121                                                Yes
# 126                                                NaN
# 133                                                Yes
# 140                                                NaN
# 147                                                NaN
# 160                                                Yes
# 161                                                Yes
# 173                                                NaN
# 174                                                NaN
# 176                                                NaN
# 183                                                Yes
# 185                                                NaN
# 186                                                NaN
# 190                                                NaN
# 204                                                NaN
# 207                                                Yes
# 208                                                NaN
#
#      population_number_of_people  e_waste_tons_year  total_waste_generated  \
# 0                         103187                NaN           8.813202e+04
# 4                          82431                NaN           4.300000e+04
# 8                          55599                NaN           1.898949e+04
# 24                         64798                NaN           8.200000e+04
# 34                        164541                NaN           1.789330e+05
# 39                      78736152                NaN           1.438523e+07
# 40                       2648507                NaN           4.512000e+05
# 45                      11303687                NaN           2.692692e+06
# 46                        153822                NaN           2.470381e+04
# 47                         59172                NaN           6.000000e+04
# 52                         72400                NaN           1.317600e+04
# 65                         48842                NaN           6.100000e+04
# 75                       1221490                NaN           1.984431e+05
# 78                         56905                NaN           5.000000e+04
# 80                        159973                NaN           1.415000e+05
# 88                         80759                NaN           5.055100e+04
# 109                      3512932                NaN           5.644667e+05
# 119                        30959                NaN           1.547950e+04
# 121                        37783                NaN           4.600000e+04
# 126                        52793                NaN           8.614000e+03
# 133                        54036                NaN           3.276141e+04
# 140                       278000                NaN           1.081574e+05
# 147                        13049                NaN           6.191751e+03
# 160                      4046901                NaN           1.387000e+06
# 161                       273528                NaN           1.470000e+05
# 173                        33203                NaN           1.717468e+04
# 174                     14317996                NaN           2.326099e+06
# 176                     11177490                NaN           2.680681e+06
# 183                        37685                NaN                    NaN
# 185                     20824892                NaN           4.500000e+06
# 186                        34900                NaN                    NaN
# 190                      8177809                NaN           1.787400e+06
# 204                     29774500                NaN           4.000000e+06
# 207                        20645                NaN           2.109919e+04
# 208                       105784                NaN           1.465000e+05
#
#     population_buckets
# 0                  NaN
# 4                  NaN
# 8                  NaN
# 24                 NaN
# 34                 NaN
# 39                <50M
# 40                 NaN
# 45                <10M
# 46                 NaN
# 47                 NaN
# 52                 NaN
# 65                 NaN
# 75                 NaN
# 78                 NaN
# 80                 NaN
# 88                 NaN
# 109                NaN
# 119                NaN
# 121                NaN
# 126                NaN
# 133                NaN
# 140                NaN
# 147                NaN
# 160                NaN
# 161                NaN
# 173                NaN
# 174               <10M
# 176               <10M
# 183                NaN
# 185               <20M
# 186                NaN
# 190                NaN
# 204               <20M
# 207                NaN
# 208                NaN

# %%
world_df['total_waste_generated'].describe().apply(lambda x: format(int(x), 'f'))
# Out:
# count          215.000000
# mean       9638989.000000
# std       36002157.000000
# min           3989.000000
# 25%         213879.000000
# 50%        1787400.000000
# 75%        5282711.000000
# max      395081376.000000
# Name: total_waste_generated, dtype: object

# %%
world_df['gdp'].describe().apply(lambda x: format(int(x), 'f'))
# Out:
# count       216.000000
# mean      22645.000000
# std       22663.000000
# min         822.000000
# 25%        4799.000000
# 50%       13465.000000
# 75%       35911.000000
# max      117335.000000
# Name: gdp, dtype: object

# %% [markdown]
# # Cleaning

# %% [markdown]
# #### Cleaned the data by keeping all the columns required for the analysis in a columns_to_keep dataframe and assigning it to new variable world_df

# %%
columns_to_keep = ['iso3c','region_id','country_name','income_id','gdp','composition_food_organic_waste_percent',
                   'composition_plastic_percent',
                   'other_information_national_law_governing_solid_waste_management_in_the_country',
                   'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
                   'population_number_of_people','e_waste_tons_year','total_waste_generated'
]

world_df = world_df[columns_to_keep]

# %% [markdown]
# ##### Replacing the NA and None value with "No"

# %%
world_df['other_information_summary_of_key_solid_waste_information_made_available_to_the_public'].replace("None", pd.NA, inplace=True)
world_df['other_information_summary_of_key_solid_waste_information_made_available_to_the_public'].replace(pd.NA, "No", inplace=True)
# Out:
# C:\Users\Khalid Waquar\AppData\Local\Temp\ipykernel_23752\3499905995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   world_df['other_information_summary_of_key_solid_waste_information_made_available_to_the_public'].replace("None", pd.NA, inplace=True)
# C:\Users\Khalid Waquar\AppData\Local\Temp\ipykernel_23752\3499905995.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   world_df['other_information_summary_of_key_solid_waste_information_made_available_to_the_public'].replace(pd.NA, "No", inplace=True)

# %% [markdown]
# ##### Dropping the rows with NA values in columns "composition_food_organic_waste_percent", "composition_plastic_percent", "e_waste_tons_year"

# %%
world_df = world_df.dropna(subset=["composition_food_organic_waste_percent", "composition_plastic_percent", "e_waste_tons_year"])

# %% [markdown]
# ##### Replacing income_id codes with understandble Income Labels

# %%
world_df['income_id'].replace("HIC", 'High-Income-Country', inplace=True)
world_df['income_id'].replace("LIC", 'Low-Income-Country', inplace=True)
world_df['income_id'].replace("LMC", 'LowToMedium-Income-Country', inplace=True)
world_df['income_id'].replace("UMC", 'Medium-Income-Country', inplace=True)

world_df['other_information_national_law_governing_solid_waste_management_in_the_country'].replace("yes", 'Yes', inplace=True)

# %% [markdown]
# # Analyzing and Plotting

# %% [markdown]
# We are analyzing the amount of waste generated by the countries based on their Income levels

# %%
analyze_df = world_df.groupby(['income_id']).agg({'total_waste_generated':"sum"}).reset_index()
analyze_df["total_waste_generated"] = analyze_df["total_waste_generated"].astype("int64")
analyze_df.rename(columns={"income_id": "income_slab"},inplace=True)

# %%
import altair as alt

alt.renderers.enable("mimetype")
bars = alt.Chart(analyze_df).mark_bar().encode(
    x="income_slab",
    y="total_waste_generated",
    color=alt.Color('income_slab:N', scale=alt.Scale(scheme='category10'))
).properties(
    width=600,
    height=300
)

labels = bars.mark_text(
    align='center',
    baseline='bottom',
    dy=-5  # adjust offset to avoid overlapping with bars
).encode(
    text='total_waste_generated'
)

(bars + labels).properties(
    width=600,
    height=300
)
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# The donut chart below describes it the data on waste managment is made available to the population of their country. You can see the data labels and the percentages if you hover over the donut chart

# %%
world_df['other_information_summary_of_key_solid_waste_information_made_available_to_the_public'].value_counts()
# Out:
# No     104
# Yes     48
# Name: other_information_summary_of_key_solid_waste_information_made_available_to_the_public, dtype: int64

# %%
# Aggregate data
analyze_df2 = world_df.groupby("other_information_summary_of_key_solid_waste_information_made_available_to_the_public")["country_name"].count().reset_index()
analyze_df2.rename(columns={"country_name": "count"}, inplace=True)

# Calculate total count
total_count = analyze_df2["count"].sum()

# Calculate percentage share
analyze_df2["share"] = analyze_df2["count"]/total_count * 100

# Create donut chart with legend
donut_chart = alt.Chart(analyze_df2, title='Donut Chart').mark_arc().encode(
    theta='count',
    color=alt.Color('other_information_summary_of_key_solid_waste_information_made_available_to_the_public', legend=alt.Legend(title='Data Available To Public?', orient='right')),
    tooltip=['other_information_summary_of_key_solid_waste_information_made_available_to_the_public', 'count', 'share']
).transform_calculate(
    end_angle='2 * PI * datum.count / {}'.format(total_count)
).transform_calculate(
    start_angle='datum.end_angle - PI * datum.count / {}'.format(total_count)
).transform_filter(
    alt.datum.count > 0
).properties(
    width=300,
    height=300
).configure_arc(
    innerRadius=70,
    strokeWidth=2
)

donut_chart
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# Analyzing here what percentage ofcountries have a centralized governing body for their waste management in their country. Hover over the chart to see data labels

# %%
world_df['other_information_national_law_governing_solid_waste_management_in_the_country'].value_counts()
# Out:
# Yes    132
# No      14
# Name: other_information_national_law_governing_solid_waste_management_in_the_country, dtype: int64

# %%
analyze_df3 = world_df.groupby("other_information_national_law_governing_solid_waste_management_in_the_country")["country_name"].count().reset_index()
analyze_df3.rename(columns={"country_name": "count"}, inplace=True)

# %%
chart = alt.Chart(analyze_df3, title='Pie Chart').mark_arc().encode(
    theta='count:Q',
    color=alt.Color('other_information_national_law_governing_solid_waste_management_in_the_country:N', scale=alt.Scale(range=['#6baed6', '#fdbf6f'])),
    tooltip=['other_information_national_law_governing_solid_waste_management_in_the_country:N', 'count:Q'],  # Data labels to be displayed on hover
    text=alt.Text('count:Q', format='.2s'),  # Data labels to be displayed on the chart
).properties(
    width=400,
    height=300
)
chart
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# Breaking down by GDP

# %%
world_df["gdp"].describe()
# Out:
# count       152.000000
# mean      24379.931221
# std       23138.064409
# min         839.778503
# 25%        7311.291138
# 50%       16120.015135
# 75%       37380.665040
# max      117335.585900
# Name: gdp, dtype: float64

# %% [markdown]
# Making brackets of GPD for each country

# %%
def add_gpd_bracket(gdp: int):
    if gdp<10000:
        return "low_gdp"
    elif gdp<15000:
        return "medium_gdp" 
    else:
        return "high_gdp"     
world_df["gdp_bracket"] = world_df["gdp"].apply(add_gpd_bracket)

world_df[["gdp","gdp_bracket"]]
# Out:
#               gdp gdp_bracket
# 2     8036.690430     low_gdp
# 3    13724.058590  medium_gdp
# 5    67119.132810    high_gdp
# 6    23550.099610    high_gdp
# 7    11019.838870  medium_gdp
# ..            ...         ...
# 211   6210.983398     low_gdp
# 212   9723.561523     low_gdp
# 213   8269.671875     low_gdp
# 214  12666.607420  medium_gdp
# 216   3190.506592     low_gdp
#
# [152 rows x 2 columns]

# %%
world_df['gdp_bracket'].value_counts()
# Out:
# high_gdp      79
# low_gdp       48
# medium_gdp    25
# Name: gdp_bracket, dtype: int64

# %% [markdown]
# Analyzing how many of these waste managment countries has low , medium or high GDP

# %%
analyze_df4 = world_df.groupby("gdp_bracket")["country_name"].count().reset_index()
analyze_df4.rename(columns={"country_name": "count"}, inplace=True)

# %%
alt.Chart(analyze_df4).mark_bar().encode(
    x="gdp_bracket",
    y="count",
    color=alt.Color('gdp_bracket:N', scale=alt.Scale(scheme='category10'))

).properties(
    width=300,
    height=300
)
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
world_df["ewaste_perc"]=(world_df['e_waste_tons_year'] * 100)/world_df['total_waste_generated']
world_df[["ewaste_perc", "e_waste_tons_year", "total_waste_generated"]]
# Out:
#      ewaste_perc  e_waste_tons_year  total_waste_generated
# 2       2.183384            92000.0           4.213644e+06
# 3       1.839171            20000.0           1.087447e+06
# 5       2.385325           134000.0           5.617682e+06
# 6       1.628649           291700.0           1.791055e+07
# 7       2.840909            14000.0           4.928000e+05
# ..           ...                ...                    ...
# 211     1.824878              500.0           2.739909e+04
# 212     0.007210               23.0           3.190000e+05
# 213     0.868339            42000.0           4.836820e+06
# 214     1.739156           321000.0           1.845723e+07
# 216     0.896705            13000.0           1.449752e+06
#
# [152 rows x 3 columns]

# %%
world_df["waste_per_person_in_lbs"] = (world_df['total_waste_generated']/world_df['population_number_of_people'])*2204
world_df[["country_name","waste_per_person_in_lbs"]]
# Out:
#              country_name  waste_per_person_in_lbs
# 2                  Angola               370.051600
# 3                 Albania               839.723984
# 5    United Arab Emirates              1267.216046
# 6               Argentina               918.414609
# 7                 Armenia               373.726421
# ..                    ...                      ...
# 211                 Samoa               321.784000
# 212                Kosovo               390.207570
# 213           Yemen, Rep.               386.465681
# 214          South Africa               786.395809
# 216              Zimbabwe               255.609537
#
# [152 rows x 2 columns]

# %%
top_10 = world_df.nlargest(10, "waste_per_person_in_lbs")[["country_name", "waste_per_person_in_lbs"]]

# Build the line chart
chart = alt.Chart(top_10).mark_bar().encode(
    x='country_name:N',
    y='waste_per_person_in_lbs:Q',
    color=alt.Color('country_name:N', scale=alt.Scale(scheme='category10')),
    text=alt.Text('waste_per_person_in_lbs:Q', format='.1f')

).properties(
    title='Top Ten Countries by Waste per Person',
    width=600,
    height=400
)

chart
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# # THE PROJECT ENDS HERE

# %%
world_df["waste_per_person_in_lbs"].describe()
# Out:
# count     152.000000
# mean      826.439620
# std       479.253377
# min       110.966909
# 25%       462.771157
# 50%       764.141701
# 75%      1113.413702
# max      2646.789906
# Name: waste_per_person_in_lbs, dtype: float64

# %%
def add_wastepp_bracket(waste_per_person_in_lbs: int):
    if waste_per_person_in_lbs<500:
        return "low_waste_per_person"
    elif waste_per_person_in_lbs<1000:
        return "medium_waste_per_person" 
    else:
        return "high_waste_per_person"     
world_df["wastepp_bracket"] = world_df["waste_per_person_in_lbs"].apply(add_wastepp_bracket)

world_df[["waste_per_person_in_lbs","wastepp_bracket"]]
# Out:
#      waste_per_person_in_lbs          wastepp_bracket
# 2                 370.051600     low_waste_per_person
# 3                 839.723984  medium_waste_per_person
# 5                1267.216046    high_waste_per_person
# 6                 918.414609  medium_waste_per_person
# 7                 373.726421     low_waste_per_person
# ..                       ...                      ...
# 211               321.784000     low_waste_per_person
# 212               390.207570     low_waste_per_person
# 213               386.465681     low_waste_per_person
# 214               786.395809  medium_waste_per_person
# 216               255.609537     low_waste_per_person
#
# [152 rows x 2 columns]

# %%
world_df['wastepp_bracket'].value_counts()
# Out:
# medium_waste_per_person    64
# high_waste_per_person      45
# low_waste_per_person       43
# Name: wastepp_bracket, dtype: int64

# %%
world_df[['country_name','wastepp_bracket']].value_counts()
# Out:
# country_name  wastepp_bracket
# Albania       medium_waste_per_person    1
# Morocco       low_waste_per_person       1
# Netherlands   high_waste_per_person      1
# New Zealand   high_waste_per_person      1
# Niger         low_waste_per_person       1
#                                         ..
# Grenada       medium_waste_per_person    1
# Guatemala     low_waste_per_person       1
# Guinea        low_waste_per_person       1
# Guyana        medium_waste_per_person    1
# Zimbabwe      low_waste_per_person       1
# Length: 151, dtype: int64

# %%
# Generate data
# world_df["ewaste_perc"]=(world_df['e_waste_tons_year'] * 100)/world_df['total_waste_generated']
# data = world_df[["ewaste_perc", "e_waste_tons_year", "total_waste_generated"]]

# # Melt data to long format
# melted_data = pd.melt(data, var_name='variable', value_name='value')

# # Create chart
# # alt.Chart(data).mark_bar().encode(
# #     x=alt.X('variable:N', axis=alt.Axis(title='Variables')),
# #     y=alt.Y('value:Q', axis=alt.Axis(title='Value')),
# #     color=alt.Color('variable:N', scale=alt.Scale(scheme='category10'))
# # ).properties(
# #     width=600,
# #     height=400
# # ).configure_axis(
# #     labelFontSize=14,
# #     titleFontSize=16
# # )

# # creating a custom dataframe
# # data = pd.DataFrame([[264, 'Rohit', 'ODI'], 
# #                      [183, 'Virat', 'ODI'], 
# #                      [118, 'Rohit', 'T20'], 
# #                      [94, 'Virat', 'T20'],
# #                      [212, 'Rohit','Test'],
# #                      [254, 'Virat','Test']],
# #                      columns=['Highest Score', 'Player', 'Format'])
  
# # print(data)

# gp_chart = alt.Chart(data).mark_bar().encode(
#   alt.Column('Format'), alt.X('e_waste_tons_year'),
#   alt.Y('total_waste_generated', axis=alt.Axis(grid=False)), 
#   alt.Color('ewaste_perc'))
  
# gp_chart.display()

# %%
# Generate data
# world_df["ewaste_perc"]=(world_df['e_waste_tons_year'] * 100)/world_df['total_waste_generated']
# data = world_df[["ewaste_perc", "e_waste_tons_year", "total_waste_generated"]]


# gp_chart = alt.Chart(data).mark_bar().encode(
#   alt.Column('Format'), alt.X('e_waste_tons_year'),
#   alt.Y('total_waste_generated', axis=alt.Axis(grid=False)), 
#   alt.Color('ewaste_perc'))
  
# gp_chart.display()
